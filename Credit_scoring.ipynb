# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kabure/german-credit-data-with-risk")

print("Path to dataset files:", path)

import warnings
warnings.filterwarnings("ignore")
# Out:
# Using Colab cache for faster access to the 'german-credit-data-with-risk' dataset.
# Path to dataset files: /kaggle/input/german-credit-data-with-risk

# %%
import shutil

shutil.copytree(path, "Data1")
# Out:
# 'Data1'

# %%
import pandas as pd
credit_df=pd.read_csv("/content/Data1/german_credit_data.csv")
credit_df
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# ...

# %%
credit_df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
credit_df.tail()
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose  Risk
# 995           1736        12  furniture/equipment  good
# 996           3857        30                  car  good
# 997            804        12             radio/TV  good
# 998           1845        45             radio/TV   bad
# 999           4576        45                  car  good

# %%
credit_df.shape
# Out:
# (1000, 11)

# %%
credit_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
credit_df.shape
# Out:
# (1000, 10)

# %%
credit_df.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Risk              1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %%
credit_df.memory_usage(deep=True)
# Out:
# Index                 132
# Age                  8000
# Sex                 53620
# Job                  8000
# Housing             52287
# Saving accounts     51153
# Checking account    46350
# Credit amount        8000
# Duration             8000
# Purpose             57559
# Risk                52700
# dtype: int64

# %%
credit_df.isnull()
# Out:
#        Age    Sex    Job  Housing  Saving accounts  Checking account  \
# 0    False  False  False    False             True             False
# 1    False  False  False    False            False             False
# 2    False  False  False    False            False              True
# 3    False  False  False    False            False             False
# 4    False  False  False    False            False             False
# ..     ...    ...    ...      ...              ...               ...
# 995  False  False  False    False            False              True
# 996  False  False  False    False            False             False
# 997  False  False  False    False            False              True
# 998  False  False  False    False            False             False
# 999  False  False  False    False            False             False
#
#      Credit amount  Duration  Purpose   Risk
# 0            False     False    False  False
# 1            False     False    False  False
# ...

# %%
credit_df.isnull().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
credit_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
credit_df.describe()
# Out:
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %%
credit_df.describe(include='object')
# Out:
#          Sex Housing Saving accounts Checking account Purpose  Risk
# count   1000    1000             817              606    1000  1000
# unique     2       3               4                3       8     2
# top     male     own          little           little     car  good
# freq     690     713             603              274     337   700

# %%
num_cols = ['Age', 'Credit amount', 'Duration']
cat_cols = ['Sex', 'Housing', 'Saving accounts',
            'Checking account', 'Purpose', 'Job']

# %%
num_cols
# Out:
# ['Age', 'Credit amount', 'Duration']

# %%
cat_cols
# Out:
# ['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose', 'Job']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit_df[num_cols].hist(figsize=(15,10), bins=10)
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=credit_df,x='Risk',hue='Risk',palette=['red','green'])
plt.title("Risk Distribution")
plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(8,5))
    sns.countplot(x=col, data=credit_df,hue=col,palette='Set2')
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in num_cols:
    if col != 'Risk':
        plt.figure(figsize=(8,5))
        sns.scatterplot(x=credit_df[col], y=credit['Risk'],hue=credit['Risk'],palette='Set2')
        plt.title(f"{col} vs Risk")
        plt.show()

# %%
for col in num_cols:
    if col != 'Risk':
        plt.figure(figsize=(8,5))
        sns.boxplot(x='Risk', y=col, data=credit_df)
        plt.title(f"Risk vs {col}")
        plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=credit_df, x='Risk', hue='Saving accounts', kde=True)
plt.title("Risk Distribution by Saving accounts")
plt.xlabel("Risk")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=credit_df, x='Risk', hue='Housing', kde=True)
plt.title("Risk Distribution by Housing")
plt.xlabel("Risk")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(credit_df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.pairplot(credit_df[num_cols])
plt.show()

# %%
credit_df['Risk_num'] = credit_df['Risk'].map({'bad':0, 'good':1})
ab=credit_df.groupby('Saving accounts')['Risk_num'].mean()
ab.sort_values(ascending=False)
# Out:
# Saving accounts
# Little       NaN
# Moderate     NaN
# Quite Rich   NaN
# Rich         NaN
# Unknown      NaN
# Name: Risk_num, dtype: float64

# %%
rs= credit_df.groupby('Saving accounts')['Risk_num'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(x=credit_df['Saving accounts'], y=credit_df['Risk_num'],hue=credit_df['Saving accounts'],palette='Set2')
plt.title("Average Risk by Saving accounts")
plt.xticks(rotation=45)
plt.xlabel("Risk")
plt.ylabel("Saving accounts")
plt.show()

# %%
rd= credit_df.groupby('Job')['Risk_num'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(x=credit_df['Job'], y=credit_df['Risk_num'],hue=credit_df['Job'],palette='Set2')
plt.title("Average Risk by Job")
plt.xticks(rotation=45)
plt.xlabel("Risk")
plt.ylabel("Job")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=credit_df['Housing'], y=credit_df['Risk_num'],hue=credit_df['Housing'],palette='Set2')
plt.title("Average Risk by Housing")
plt.xticks(rotation=45)
plt.xlabel("Risk")
plt.ylabel("Housing")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=credit_df['Checking account'], y=credit_df['Risk_num'],hue=credit_df['Checking account'],palette='Set2')
plt.title("Average Risk by Checking account")
plt.xticks(rotation=45)
plt.xlabel("Risk")
plt.ylabel("Checking account")
plt.show()

# %%
credit_df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    Male    2     Own         Unknown           Little           1169
# 1     22  Female    2     Own          Little         Moderate           5951
# 2     49    Male    1     Own          Little          Unknown           2096
# 3     45    Male    2    Free          Little           Little           7882
# 4     53    Male    2    Free          Little           Little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  Female    1     Own          Little          Unknown           1736
# 996   40    Male    3     Own          Little           Little           3857
# 997   38    Male    2     Own          Little          Unknown            804
# 998   23    Male    2    Free          Little           Little           1845
# 999   27    Male    2     Own        Moderate         Moderate           4576
#
# ...

# %%
credit_df=credit_df.drop('Risk_num',axis=1)

# %%
for col in num_cols:
    plt.figure(figsize=(8,5))
    sns.boxplot(x=credit_df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# Skewness
skewness = credit_df[num_cols].skew()
skewness
# Out:
# Age              1.020739
# Credit amount    1.949628
# Duration         1.094184
# dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=skewness.index, y=skewness.values,hue=skewness.index,palette='Set2')
plt.axhline(0, color='red', linestyle='--')
plt.title("Skewness of Numerical Features")
plt.ylabel("Skewness Value")
plt.xticks(rotation=45)
plt.show()

# %%
# Kurtosis
kurtosis = credit_df[num_cols].kurtosis()
kurtosis
# Out:
# Age              0.595780
# Credit amount    4.292590
# Duration         0.919781
# dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=kurtosis.index, y=kurtosis.values,hue=kurtosis.index,palette='Set2')
plt.axhline(0, color='red', linestyle='--')
plt.title("Kurtosis of Numerical Features")
plt.ylabel("Kurtosis Value")
plt.xticks(rotation=45)
plt.show()

# %%
credit_df.isnull().sum()
# Out:
# Age                 0
# Sex                 0
# Job                 0
# Housing             0
# Saving accounts     0
# Checking account    0
# Credit amount       0
# Duration            0
# Purpose             0
# Risk                0
# dtype: int64

# %%
credit_df['Saving accounts'] = credit_df['Saving accounts'].fillna('Unknown')
credit_df['Checking account'] = credit_df['Checking account'].fillna('Unknown')

# %%
credit_df.isnull().sum()
# Out:
# Age                 0
# Sex                 0
# Job                 0
# Housing             0
# Saving accounts     0
# Checking account    0
# Credit amount       0
# Duration            0
# Purpose             0
# Risk                0
# dtype: int64

# %%
for col in cat_cols:

    if credit_df[col].dtype == 'object':

        credit_df[col] = credit_df[col].str.strip()
        credit_df[col] = credit_df[col].str.title()

# %%
for col in num_cols:
    plt.figure(figsize=(8,5))
    sns.boxplot(x=credit_df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
 # capping
def remove_outliers(credit_df,col ):
    Q1 = credit_df[col].quantile(0.25)
    Q3 = credit_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    credit_df[col] = credit_df[col].clip(lower, upper)
    return credit_df

# %%
credit_df_cap=credit_df.copy()
for col in num_cols:
  credit_df_cap=remove_outliers(credit_df_cap,col)

# %%
print("Before capping:", credit_df.shape)
print("After capping:", credit_df_cap.shape)
# Out:
# Before capping: (1000, 10)
# After capping: (1000, 10)

# %%
for col in num_cols:
    plt.figure(figsize=(10,4))

    plt.subplot(1,2,1)
    sns.boxplot(x=credit_df[col])
    plt.title(f"Before Capping: {col}")

    plt.subplot(1,2,2)
    sns.boxplot(x=credit_df_cap[col])
    plt.title(f"After Capping: {col}")

    plt.show()

# %%
X=credit_df.drop('Risk',axis=1)
Y=credit_df['Risk']

# %%
X
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    Male    2     Own         Unknown           Little           1169
# 1     22  Female    2     Own          Little         Moderate           5951
# 2     49    Male    1     Own          Little          Unknown           2096
# 3     45    Male    2    Free          Little           Little           7882
# 4     53    Male    2    Free          Little           Little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  Female    1     Own          Little          Unknown           1736
# 996   40    Male    3     Own          Little           Little           3857
# 997   38    Male    2     Own          Little          Unknown            804
# 998   23    Male    2    Free          Little           Little           1845
# 999   27    Male    2     Own        Moderate         Moderate           4576
#
# ...

# %%
Y
# Out:
# 0      Good
# 1       Bad
# 2      Good
# 3      Good
# 4       Bad
#        ...
# 995    Good
# 996    Good
# 997    Good
# 998     Bad
# 999    Good
# Name: Risk, Length: 1000, dtype: object

# %%
X_encoded = pd.get_dummies(X, drop_first=True)
X = X_encoded.astype(int)

# %%
X
# Out:
#      Age  Job  Credit amount  Duration  Sex_Male  Housing_Own  Housing_Rent  \
# 0     67    2           1169         6         1            1             0
# 1     22    2           5951        48         0            1             0
# 2     49    1           2096        12         1            1             0
# 3     45    2           7882        42         1            0             0
# 4     53    2           4870        24         1            0             0
# ..   ...  ...            ...       ...       ...          ...           ...
# 995   31    1           1736        12         0            1             0
# 996   40    3           3857        30         1            1             0
# 997   38    2            804        12         1            1             0
# 998   23    2           1845        45         1            0             0
# 999   27    2           4576        45         1            1             0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Y = le.fit_transform(credit_df["Risk"])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier
)
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
models = {
    "Logistic": LogisticRegression(),
    "SVM": SVC(kernel="rbf"),
    "Decision Tree": DecisionTreeClassifier(criterion="gini",max_depth=3),
    "Random Forest": RandomForestClassifier(n_estimators=50,criterion="gini",max_depth=3),
    "AdaBoost": AdaBoostClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "KNN": KNeighborsClassifier(n_neighbors=3),
    "XGBoost":XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier()


}

# %%
trained_models = {}

for name, model in models.items():
    model.fit(X_train, Y_train)
    trained_models[name] = model
# Out:
# [LightGBM] [Info] Number of positive: 559, number of negative: 241
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 377
# [LightGBM] [Info] Number of data points in the train set: 800, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.698750 -> initscore=0.841353
# [LightGBM] [Info] Start training from score 0.841353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
trained_models
# Out:
# {'Logistic': LogisticRegression(),
#  'SVM': SVC(),
#  'Decision Tree': DecisionTreeClassifier(max_depth=3),
#  'Random Forest': RandomForestClassifier(max_depth=3, n_estimators=50),
#  'AdaBoost': AdaBoostClassifier(),
#  'Gradient Boosting': GradientBoostingClassifier(),
#  'KNN': KNeighborsClassifier(n_neighbors=3),
#  'XGBoost': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, feature_weights=None, gamma=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
# ...

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

# %%
evaluation_results = []

for name, model in trained_models.items():
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(Y_test, y_pred)
    cm=confusion_matrix(Y_test, y_pred)
    ps = precision_score(Y_test, y_pred,average='weighted')
    rs = recall_score(Y_test, y_pred,average='weighted')
    F1 = f1_score(Y_test, y_pred,average='weighted')

    evaluation_results.append([name,accuracy,cm,ps,rs,F1])
print(evaluation_results)
results_df = pd.DataFrame(
    evaluation_results,
    columns=["Model", "Accuracy", "Confusion Matrix","Precision Score","Recall Score","F1 Score"]
)
# Out:
# [['Logistic', 0.755, array([[ 24,  35],
#        [ 14, 127]]), 0.7390009746588695, 0.755, 0.7369694804532], ['SVM', 0.77, array([[ 22,  37],
#        [  9, 132]]), 0.7600057262836419, 0.77, 0.7446093189964157], ['Decision Tree', 0.745, array([[ 26,  33],
#        [ 18, 123]]), 0.7301835664335664, 0.745, 0.7328714327743454], ['Random Forest', 0.725, array([[  4,  55],
#        [  0, 141]]), 0.8021683673469389, 0.725, 0.6274009702793086], ['AdaBoost', 0.715, array([[ 20,  39],
#        [ 18, 123]]), 0.6905409356725145, 0.715, 0.6940257221598449], ['Gradient Boosting', 0.78, array([[ 23,  36],
#        [  8, 133]]), 0.7736934529490361, 0.78, 0.7557132616487455], ['KNN', 0.705, array([[ 18,  41],
#        [ 18, 123]]), 0.67625, 0.705, 0.6804124245038827], ['XGBoost', 0.745, array([[ 26,  33],
#        [ 18, 123]]), 0.7301835664335664, 0.745, 0.7328714327743454], ['LightGBM', 0.765, array([[ 30,  29],
#        [ 18, 123]]), 0.7548684210526315, 0.765, 0.7573318235462984]]

# %%
results_df.sort_values(by="Accuracy", ascending=False)
# Out:
#                Model  Accuracy       Confusion Matrix  Precision Score  \
# 5  Gradient Boosting     0.780   [[23, 36], [8, 133]]         0.773693
# 1                SVM     0.770   [[22, 37], [9, 132]]         0.760006
# 8           LightGBM     0.765  [[30, 29], [18, 123]]         0.754868
# 0           Logistic     0.755  [[24, 35], [14, 127]]         0.739001
# 2      Decision Tree     0.745  [[26, 33], [18, 123]]         0.730184
# 7            XGBoost     0.745  [[26, 33], [18, 123]]         0.730184
# 3      Random Forest     0.725    [[4, 55], [0, 141]]         0.802168
# 4           AdaBoost     0.715  [[20, 39], [18, 123]]         0.690541
# 6                KNN     0.705  [[18, 41], [18, 123]]         0.676250
#
#    Recall Score  F1 Score
# 5         0.780  0.755713
# 1         0.770  0.744609
# 8         0.765  0.757332
# 0         0.755  0.736969
# 2         0.745  0.732871
# 7         0.745  0.732871
# 3         0.725  0.627401
# 4         0.715  0.694026
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,5))

# Accuracy comparison
plt.subplot(1, 2, 1)
plt.bar(results_df["Model"], results_df["Accuracy"])
plt.xticks(rotation=45)
plt.title("Model Comparison – Accuracy Score")
plt.ylabel("Accuracy")

# F1 Score comparison
plt.subplot(1, 2, 2)
plt.bar(results_df["Model"], results_df["F1 Score"])
plt.xticks(rotation=45)
plt.title("Model Comparison – F1 Score")
plt.ylabel("F1 Score")

plt.tight_layout()
plt.show()

# %%
best_model = results_df.sort_values(
    by=["Accuracy", "F1 Score"],
    ascending=[False, True]
).iloc[0]

print("Best Model:", best_model["Model"])
# Out:
# Best Model: Gradient Boosting

# %%
user_input={
    "Unnamed":99,
    "Age":45,
    "Sex":"male",
     "Job":2,
    "Housing":"own",
    "Saving accounts":"moderate",
    "Checking account":"moderate",
    "Credit amount":2000,
    "Duration":12,
    "Purpose":"radio/TV"
  }
user_df = pd.DataFrame([user_input])

# %%
user_df
# Out:
#    Unnamed  Age   Sex  Job Housing Saving accounts Checking account  \
# 0       99   45  male    2     own        moderate         moderate
#
#    Credit amount  Duration   Purpose
# 0           2000        12  radio/TV

# %%
user_encoded = pd.get_dummies(user_df)
user_encoded = user_encoded.reindex(columns=X_encoded.columns, fill_value=0)

# %%
user_scaled = scaler.transform(user_encoded)
prediction = model.predict(user_scaled)

# %%
prediction = model.predict(user_scaled)

risk = le.inverse_transform(prediction)

print("The Credit Risk of the Customer is :", risk[0])
# Out:
# The Credit Risk of the Customer is : Good
